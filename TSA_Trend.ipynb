# %%
# Import the libraries
import numpy as np
import pandas as pd
from fbprophet import Prophet
from fbprophet.plot import add_changepoints_to_plot

# %%
# Upload the data
from google.colab import files
uploded = files.upload()
# Out:
#      <input type="file" id="files-3b360536-55bc-4104-97dd-a0599fd6aca6" name="files[]" multiple disabled />
#      <output id="result-3b360536-55bc-4104-97dd-a0599fd6aca6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving HospitalityEmployees.csv to HospitalityEmployees.csv

# %%
# Get the data and take a look
df = pd.read_csv("HospitalityEmployees.csv")
df.head()
# Out:
#        Date  Employees
# 0  1/1/1990     1064.5
# 1  2/1/1990     1074.5
# 2  3/1/1990     1090.0
# 3  4/1/1990     1097.4
# 4  5/1/1990     1108.7

# %%
# Change the columns a/c to prophet 
df.columns = ["ds", "y"]
df["ds"] = pd.to_datetime(df["ds"])

# %%
# Plot the dataframe
df.plot(x = "ds", y = "y", figsize = (12, 8))

# %%
# Creating a model
m = Prophet()
m.fit(df)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# Applying the model
future = m.make_future_dataframe(periods = 12, freq = "MS")
forecast = m.predict(future)

# %%
# Let's plot the forecast
fig = m.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), m, forecast)
